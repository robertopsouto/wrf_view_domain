# %% [markdown]
# <a href="https://colab.research.google.com/github/robertopsouto/wrf_view_domain/blob/main/dominio_wrf.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Preparação de domínio no WRF

# %%
# !pip install salem
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 1.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 47.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 62.5 MB/s eta 0:00:00
# ...

# %%
import salem
ds = salem.open_xr_dataset('met_em.d01.2018-06-01_00_00_00.nc')
ds
# Out:
# <xarray.Dataset>
# Dimensions:      (Time: 1, num_metgrid_levels: 32, south_north: 63,
#                   west_east: 63, num_st_layers: 4, num_sm_layers: 4,
#                   south_north_stag: 64, west_east_stag: 64,
#                   z-dimension0012: 12, z-dimension0016: 16, z-dimension0021: 21)
# Coordinates:
#   * west_east    (west_east) float64 -2.79e+05 -2.7e+05 ... 2.7e+05 2.79e+05
#   * south_north  (south_north) float64 -4.042e+05 -3.952e+05 ... 1.538e+05
# Dimensions without coordinates: Time, num_metgrid_levels, num_st_layers,
#                                 num_sm_layers, south_north_stag,
#                                 west_east_stag, z-dimension0012,
#                                 z-dimension0016, z-dimension0021
# Data variables: (12/89)
#     Times        (Time) |S19 ...
#     PRES         (Time, num_metgrid_levels, south_north, west_east) float32 ...
#     SOIL_LAYERS  (Time, num_st_layers, south_north, west_east) float32 ...
# ...
